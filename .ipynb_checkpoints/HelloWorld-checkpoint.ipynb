# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # My first markdown heading

# %% [markdown]
# ## My second markdown heading

# %% [markdown]
# This is some **Bold** text

# %% [markdown]
# 1. first
# 2. second
# 3. third

# %%
my_var = 5

# %%
result = my_var*2

# %%
print(result)
# Out:
# 10
